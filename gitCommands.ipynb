# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/My Drive/Datascience projects
# Out:
# /content/gdrive/My Drive/Datascience projects

# %%
# !pwd
# Out:
# /content/gdrive/My Drive/Datascience projects

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/gdrive/MyDrive/Datascience projects/.git/

# %%
# !git remote add origin https://DanielleOriane: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@github.com/DanielleOriane/Data_science_projects.git
# !git remote -v
# Out:
# origin	https://DanielleOriane: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@github.com/DanielleOriane/Data_science_projects.git (fetch)
# origin	https://DanielleOriane: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@github.com/DanielleOriane/Data_science_projects.git (push)

# %%
! git config --global user.name "DanielleOriane"
! git config --global user.email "orianed@ymail.com"
